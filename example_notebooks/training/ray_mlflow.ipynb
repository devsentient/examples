# %% [markdown]
# ## Use Ray Tune and MLFlow on Hyperplane

# %%
# !pip install tensorboardX --quiet
# !pip install kubernetes==18.20 --quiet

# %%
import ray
import tensorflow as tf
import torch 
print(f'ray version {ray.__version__}')
print(f'tf version {tf.__version__}')
print(f'torch version {torch.__version__}')
# Out:
# 2021-09-03 17:06:24.358150: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# ray version 1.5.2
# tf version 2.4.1
# torch version 1.7.1+cpu

# %%
## start the ray cluster
from ray_common import initialize_ray_cluster, stop_ray_cluster

num_workers = 2
cpu_per_worker="4000m"
ram_per_worker="4.0Gi"


ray_cluster = initialize_ray_cluster(num_workers, cpu_per_worker, ram_per_worker)
ray_cluster
# Out:
# 2021-09-03 17:08:14,500	INFO services.py:1245 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-09-03 17:08:14,505	WARNING services.py:1706 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=2.37gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# Waiting for worker ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98...
# Waiting for worker ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925...
# ['ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98',
#  'ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925']

# %%
assert ray.worker.global_worker.connected

# %%
import os
import tempfile
import time

import mlflow

from ray import tune
from ray.tune.integration.mlflow import MLflowLoggerCallback, mlflow_mixin
print('mlflow version', mlflow.__version__)
# Out:
# mlflow version 1.17.0

# %%
def evaluation_fn(step, width, height):
    return (0.1 + width * step / 100)**(-1) + height * 0.1

# %%
def easy_objective(config):
    # Hyperparameters
    width, height = config["width"], config["height"]

    for step in range(config.get("steps", 100)):
        # Iterative training function - can be any arbitrary training procedure
        intermediate_score = evaluation_fn(step, width, height)
        # Feed the score back to Tune.
        tune.report(iterations=step, mean_loss=intermediate_score)
        time.sleep(0.1)

# %%
def tune_function(mlflow_tracking_uri, finish_fast=False):
    tune.run(
        easy_objective,
        name="mlflow",
        num_samples=5,
        callbacks=[
            MLflowLoggerCallback(
                tracking_uri=mlflow_tracking_uri,
                experiment_name="mixin_example",
                save_artifact=True)
        ],
        config={
            "width": tune.randint(10, 100),
            "height": tune.randint(0, 100),
            "steps": 5 if finish_fast else 100,
        })

# %%
@mlflow_mixin
def decorated_easy_objective(config):
    # Hyperparameters
    width, height = config["width"], config["height"]

    for step in range(config.get("steps", 100)):
        # Iterative training function - can be any arbitrary training procedure
        intermediate_score = evaluation_fn(step, width, height)
        # Log the metrics to mlflow
        mlflow.log_metrics(dict(mean_loss=intermediate_score), step=step)
        # Feed the score back to Tune.
        tune.report(iterations=step, mean_loss=intermediate_score)
        time.sleep(0.1)

# %%
def tune_decorated(mlflow_tracking_uri, finish_fast=False):
    # Set the experiment, or create a new one if does not exist yet.
    mlflow.set_tracking_uri(mlflow_tracking_uri)
    mlflow.set_experiment(experiment_name="mixin_example")
    tune.run(
        decorated_easy_objective,
        name="mlflow",
        num_samples=5,
        config={
            "width": tune.randint(10, 100),
            "height": tune.randint(0, 100),
            "steps": 5 if finish_fast else 100,
            "mlflow": {
                "experiment_name": "mixin_example",
                "tracking_uri": mlflow.get_tracking_uri()
            }
        })

# %% [markdown]
# ## setup MLFlow tracking URI

# %%
import os
tracking_uri = os.environ.get('DATABASE_URL_NO_PARAMS').split(':5432')[0]
mlflow.set_tracking_uri(tracking_uri)
tracking_uri = mlflow.get_tracking_uri()
print(tracking_uri)

# %%
tune_decorated(tracking_uri)
# Out:
# 2021-09-03 17:13:10,065	WARNING function_runner.py:544 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==<br>Memory usage on this node: 1.7/7.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/9 CPUs, 0/0 GPUs, 0.0/9.85 GiB heap, 0.0/4.53 GiB objects<br>Result logdir: /root/ray_results/mlflow<br>Number of trials: 5/5 (5 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc  </th><th style="text-align: right;">  height</th><th style="text-align: right;">  width</th></tr>
# </thead>
# <tbody>
# <tr><td>decorated_easy_objective_36bc0_00000</td><td>PENDING </td><td>     </td><td style="text-align: right;">      91</td><td style="text-align: right;">     26</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00001</td><td>PENDING </td><td>     </td><td style="text-align: right;">      61</td><td style="text-align: right;">     97</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00002</td><td>PENDING </td><td>     </td><td style="text-align: right;">      26</td><td style="text-align: right;">     58</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00003</td><td>PENDING </td><td>     </td><td style="text-align: right;">      82</td><td style="text-align: right;">     74</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00004</td><td>PENDING </td><td>     </td><td style="text-align: right;">      57</td><td style="text-align: right;">     14</td></tr>
# </tbody>
# </table><br><br>
# 2021-09-03 17:13:11,457	ERROR syncer.py:72 -- Log sync requires rsync to be installed.
# Result for decorated_easy_objective_36bc0_00002:
#   date: 2021-09-03_17-13-13
#   done: false
#   experiment_id: c1ffe078065b4841858384a55ee9baae
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 0
#   iterations_since_restore: 1
#   mean_loss: 12.6
#   neg_mean_loss: -12.6
#   node_ip: 10.0.179.4
#   pid: 66
#   time_since_restore: 0.10284662246704102
#   time_this_iter_s: 0.10284662246704102
#   time_total_s: 0.10284662246704102
#   timestamp: 1630689193
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 36bc0_00002
#
# Result for decorated_easy_objective_36bc0_00003:
#   date: 2021-09-03_17-13-13
#   done: false
#   experiment_id: d824e4a05adf4fb5a7cc5249962b6796
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 0
#   iterations_since_restore: 1
#   mean_loss: 18.200000000000003
#   neg_mean_loss: -18.200000000000003
#   node_ip: 10.0.179.3
#   pid: 65
#   time_since_restore: 0.16285395622253418
#   time_this_iter_s: 0.16285395622253418
#   time_total_s: 0.16285395622253418
#   timestamp: 1630689193
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 36bc0_00003
#
# Result for decorated_easy_objective_36bc0_00000:
#   date: 2021-09-03_17-13-13
#   done: false
#   experiment_id: df826e3298c242b7891af98d2cf2265c
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 0
#   iterations_since_restore: 1
#   mean_loss: 19.1
#   neg_mean_loss: -19.1
#   node_ip: 10.0.179.3
#   pid: 64
#   time_since_restore: 0.16845941543579102
#   time_this_iter_s: 0.16845941543579102
#   time_total_s: 0.16845941543579102
#   timestamp: 1630689193
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 36bc0_00000
#
# Result for decorated_easy_objective_36bc0_00001:
#   date: 2021-09-03_17-13-13
#   done: false
#   experiment_id: 2b7b350a3bdf4d22bdff6806e94cf135
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 0
#   iterations_since_restore: 1
#   mean_loss: 16.1
#   neg_mean_loss: -16.1
#   node_ip: 10.0.179.4
#   pid: 64
#   time_since_restore: 0.08457064628601074
#   time_this_iter_s: 0.08457064628601074
#   time_total_s: 0.08457064628601074
#   timestamp: 1630689193
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 36bc0_00001
#
# Result for decorated_easy_objective_36bc0_00004:
#   date: 2021-09-03_17-13-13
#   done: false
#   experiment_id: bf16f9be9b3644148e068a75743168a1
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 0
#   iterations_since_restore: 1
#   mean_loss: 15.7
#   neg_mean_loss: -15.7
#   node_ip: 10.0.179.4
#   pid: 65
#   time_since_restore: 0.13671040534973145
#   time_this_iter_s: 0.13671040534973145
#   time_total_s: 0.13671040534973145
#   timestamp: 1630689193
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 36bc0_00004
# == Status ==<br>Memory usage on this node: 1.7/7.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 5.0/9 CPUs, 0/0 GPUs, 0.0/9.85 GiB heap, 0.0/4.53 GiB objects<br>Result logdir: /root/ray_results/mlflow<br>Number of trials: 5/5 (5 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc          </th><th style="text-align: right;">  height</th><th style="text-align: right;">  width</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th><th style="text-align: right;">  neg_mean_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>decorated_easy_objective_36bc0_00000</td><td>RUNNING </td><td>10.0.179.3:64</td><td style="text-align: right;">      91</td><td style="text-align: right;">     26</td><td style="text-align: right;">9.43784</td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.17164</td><td style="text-align: right;">          11</td><td style="text-align: right;">       -9.43784</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00001</td><td>RUNNING </td><td>10.0.179.4:64</td><td style="text-align: right;">      61</td><td style="text-align: right;">     97</td><td style="text-align: right;">6.18518</td><td style="text-align: right;">    13</td><td style="text-align: right;">         2.14049</td><td style="text-align: right;">          12</td><td style="text-align: right;">       -6.18518</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00002</td><td>RUNNING </td><td>10.0.179.4:66</td><td style="text-align: right;">      26</td><td style="text-align: right;">     58</td><td style="text-align: right;">2.74164</td><td style="text-align: right;">    13</td><td style="text-align: right;">         2.13614</td><td style="text-align: right;">          12</td><td style="text-align: right;">       -2.74164</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00003</td><td>RUNNING </td><td>10.0.179.3:65</td><td style="text-align: right;">      82</td><td style="text-align: right;">     74</td><td style="text-align: right;">8.31136</td><td style="text-align: right;">    13</td><td style="text-align: right;">         2.27568</td><td style="text-align: right;">          12</td><td style="text-align: right;">       -8.31136</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00004</td><td>RUNNING </td><td>10.0.179.4:65</td><td style="text-align: right;">      57</td><td style="text-align: right;">     14</td><td style="text-align: right;">6.30976</td><td style="text-align: right;">    12</td><td style="text-align: right;">         2.11566</td><td style="text-align: right;">          11</td><td style="text-align: right;">       -6.30976</td></tr>
# </tbody>
# </table><br><br>
# Result for decorated_easy_objective_36bc0_00000:
#   date: 2021-09-03_17-13-18
#   done: false
#   experiment_id: df826e3298c242b7891af98d2cf2265c
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 29
#   iterations_since_restore: 30
#   mean_loss: 9.23089005235602
#   neg_mean_loss: -9.23089005235602
#   node_ip: 10.0.179.3
#   pid: 64
#   time_since_restore: 5.217756271362305
#   time_this_iter_s: 0.16892600059509277
#   time_total_s: 5.217756271362305
#   timestamp: 1630689198
#   timesteps_since_restore: 0
#   training_iteration: 30
#   trial_id: 36bc0_00000
#
# Result for decorated_easy_objective_36bc0_00004:
#   date: 2021-09-03_17-13-18
#   done: false
#   experiment_id: bf16f9be9b3644148e068a75743168a1
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 29
#   iterations_since_restore: 30
#   mean_loss: 5.940384615384616
#   neg_mean_loss: -5.940384615384616
#   node_ip: 10.0.179.4
#   pid: 65
#   time_since_restore: 5.195038557052612
#   time_this_iter_s: 0.17796707153320312
#   time_total_s: 5.195038557052612
#   timestamp: 1630689198
#   timesteps_since_restore: 0
#   training_iteration: 30
#   trial_id: 36bc0_00004
#
# Result for decorated_easy_objective_36bc0_00002:
#   date: 2021-09-03_17-13-18
#   done: false
#   experiment_id: c1ffe078065b4841858384a55ee9baae
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 30
#   iterations_since_restore: 31
#   mean_loss: 2.657142857142857
#   neg_mean_loss: -2.657142857142857
#   node_ip: 10.0.179.4
#   pid: 66
#   time_since_restore: 5.200206279754639
#   time_this_iter_s: 0.17912077903747559
#   time_total_s: 5.200206279754639
#   timestamp: 1630689198
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 36bc0_00002
#
# Result for decorated_easy_objective_36bc0_00001:
#   date: 2021-09-03_17-13-18
#   done: false
#   experiment_id: 2b7b350a3bdf4d22bdff6806e94cf135
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 30
#   iterations_since_restore: 31
#   mean_loss: 6.134246575342466
#   neg_mean_loss: -6.134246575342466
#   node_ip: 10.0.179.4
#   pid: 64
#   time_since_restore: 5.218143939971924
#   time_this_iter_s: 0.17046308517456055
#   time_total_s: 5.218143939971924
#   timestamp: 1630689198
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 36bc0_00001
#
# Result for decorated_easy_objective_36bc0_00003:
#   date: 2021-09-03_17-13-18
#   done: false
#   experiment_id: d824e4a05adf4fb5a7cc5249962b6796
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 30
#   iterations_since_restore: 31
#   mean_loss: 8.244843049327356
#   neg_mean_loss: -8.244843049327356
#   node_ip: 10.0.179.3
#   pid: 65
#   time_since_restore: 5.34235692024231
#   time_this_iter_s: 0.17296838760375977
#   time_total_s: 5.34235692024231
#   timestamp: 1630689198
#   timesteps_since_restore: 0
#   training_iteration: 31
#   trial_id: 36bc0_00003
# == Status ==<br>Memory usage on this node: 1.7/7.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 5.0/9 CPUs, 0/0 GPUs, 0.0/9.85 GiB heap, 0.0/4.53 GiB objects (0.0/1.0 CPU_group_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_0_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_0_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_0_85fbf98a6c73bd089f176d21c53a3f34, 0.0/1.0 CPU_group_0_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_0_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_85fbf98a6c73bd089f176d21c53a3f34)<br>Result logdir: /root/ray_results/mlflow<br>Number of trials: 5/5 (5 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc          </th><th style="text-align: right;">  height</th><th style="text-align: right;">  width</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th><th style="text-align: right;">  neg_mean_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>decorated_easy_objective_36bc0_00000</td><td>RUNNING </td><td>10.0.179.3:64</td><td style="text-align: right;">      91</td><td style="text-align: right;">     26</td><td style="text-align: right;">9.19524</td><td style="text-align: right;">    41</td><td style="text-align: right;">         7.19552</td><td style="text-align: right;">          40</td><td style="text-align: right;">       -9.19524</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00001</td><td>RUNNING </td><td>10.0.179.4:64</td><td style="text-align: right;">      61</td><td style="text-align: right;">     97</td><td style="text-align: right;">6.12571</td><td style="text-align: right;">    41</td><td style="text-align: right;">         7.0739 </td><td style="text-align: right;">          40</td><td style="text-align: right;">       -6.12571</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00002</td><td>RUNNING </td><td>10.0.179.4:66</td><td style="text-align: right;">      26</td><td style="text-align: right;">     58</td><td style="text-align: right;">2.64188</td><td style="text-align: right;">    42</td><td style="text-align: right;">         7.21684</td><td style="text-align: right;">          41</td><td style="text-align: right;">       -2.64188</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00003</td><td>RUNNING </td><td>10.0.179.3:65</td><td style="text-align: right;">      82</td><td style="text-align: right;">     74</td><td style="text-align: right;">8.23367</td><td style="text-align: right;">    41</td><td style="text-align: right;">         7.152  </td><td style="text-align: right;">          40</td><td style="text-align: right;">       -8.23367</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00004</td><td>RUNNING </td><td>10.0.179.4:65</td><td style="text-align: right;">      57</td><td style="text-align: right;">     14</td><td style="text-align: right;">5.87544</td><td style="text-align: right;">    41</td><td style="text-align: right;">         7.18503</td><td style="text-align: right;">          40</td><td style="text-align: right;">       -5.87544</td></tr>
# </tbody>
# </table><br><br>
# Result for decorated_easy_objective_36bc0_00000:
#   date: 2021-09-03_17-13-23
#   done: false
#   experiment_id: df826e3298c242b7891af98d2cf2265c
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 58
#   iterations_since_restore: 59
#   mean_loss: 9.165876152832674
#   neg_mean_loss: -9.165876152832674
#   node_ip: 10.0.179.3
#   pid: 64
#   time_since_restore: 10.30574893951416
#   time_this_iter_s: 0.16855120658874512
#   time_total_s: 10.30574893951416
#   timestamp: 1630689203
#   timesteps_since_restore: 0
#   training_iteration: 59
#   trial_id: 36bc0_00000
#
# Result for decorated_easy_objective_36bc0_00004:
#   date: 2021-09-03_17-13-23
#   done: false
#   experiment_id: bf16f9be9b3644148e068a75743168a1
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 58
#   iterations_since_restore: 59
#   mean_loss: 5.821654501216545
#   neg_mean_loss: -5.821654501216545
#   node_ip: 10.0.179.4
#   pid: 65
#   time_since_restore: 10.295065641403198
#   time_this_iter_s: 0.17229461669921875
#   time_total_s: 10.295065641403198
#   timestamp: 1630689203
#   timesteps_since_restore: 0
#   training_iteration: 59
#   trial_id: 36bc0_00004
#
# Result for decorated_easy_objective_36bc0_00002:
#   date: 2021-09-03_17-13-23
#   done: false
#   experiment_id: c1ffe078065b4841858384a55ee9baae
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 59
#   iterations_since_restore: 60
#   mean_loss: 2.6291375291375294
#   neg_mean_loss: -2.6291375291375294
#   node_ip: 10.0.179.4
#   pid: 66
#   time_since_restore: 10.30201244354248
#   time_this_iter_s: 0.16910982131958008
#   time_total_s: 10.30201244354248
#   timestamp: 1630689203
#   timesteps_since_restore: 0
#   training_iteration: 60
#   trial_id: 36bc0_00002
#
# Result for decorated_easy_objective_36bc0_00001:
#   date: 2021-09-03_17-13-23
#   done: false
#   experiment_id: 2b7b350a3bdf4d22bdff6806e94cf135
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 59
#   iterations_since_restore: 60
#   mean_loss: 6.117442874585732
#   neg_mean_loss: -6.117442874585732
#   node_ip: 10.0.179.4
#   pid: 64
#   time_since_restore: 10.318778276443481
#   time_this_iter_s: 0.16640973091125488
#   time_total_s: 10.318778276443481
#   timestamp: 1630689203
#   timesteps_since_restore: 0
#   training_iteration: 60
#   trial_id: 36bc0_00001
#
# Result for decorated_easy_objective_36bc0_00003:
#   date: 2021-09-03_17-13-23
#   done: false
#   experiment_id: d824e4a05adf4fb5a7cc5249962b6796
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 59
#   iterations_since_restore: 60
#   mean_loss: 8.222851919561244
#   neg_mean_loss: -8.222851919561244
#   node_ip: 10.0.179.3
#   pid: 65
#   time_since_restore: 10.405247211456299
#   time_this_iter_s: 0.16343450546264648
#   time_total_s: 10.405247211456299
#   timestamp: 1630689203
#   timesteps_since_restore: 0
#   training_iteration: 60
#   trial_id: 36bc0_00003
# == Status ==<br>Memory usage on this node: 1.7/7.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 5.0/9 CPUs, 0/0 GPUs, 0.0/9.85 GiB heap, 0.0/4.53 GiB objects (0.0/1.0 CPU_group_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_0_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_0_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_0_85fbf98a6c73bd089f176d21c53a3f34, 0.0/1.0 CPU_group_0_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_0_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_85fbf98a6c73bd089f176d21c53a3f34)<br>Result logdir: /root/ray_results/mlflow<br>Number of trials: 5/5 (5 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc          </th><th style="text-align: right;">  height</th><th style="text-align: right;">  width</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th><th style="text-align: right;">  neg_mean_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>decorated_easy_objective_36bc0_00000</td><td>RUNNING </td><td>10.0.179.3:64</td><td style="text-align: right;">      91</td><td style="text-align: right;">     26</td><td style="text-align: right;">9.15543</td><td style="text-align: right;">    70</td><td style="text-align: right;">         12.1575</td><td style="text-align: right;">          69</td><td style="text-align: right;">       -9.15543</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00001</td><td>RUNNING </td><td>10.0.179.4:64</td><td style="text-align: right;">      61</td><td style="text-align: right;">     97</td><td style="text-align: right;">6.11492</td><td style="text-align: right;">    70</td><td style="text-align: right;">         12.0417</td><td style="text-align: right;">          69</td><td style="text-align: right;">       -6.11492</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00002</td><td>RUNNING </td><td>10.0.179.4:66</td><td style="text-align: right;">      26</td><td style="text-align: right;">     58</td><td style="text-align: right;">2.62457</td><td style="text-align: right;">    71</td><td style="text-align: right;">         12.2459</td><td style="text-align: right;">          70</td><td style="text-align: right;">       -2.62457</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00003</td><td>RUNNING </td><td>10.0.179.3:65</td><td style="text-align: right;">      82</td><td style="text-align: right;">     74</td><td style="text-align: right;">8.21927</td><td style="text-align: right;">    71</td><td style="text-align: right;">         12.2379</td><td style="text-align: right;">          70</td><td style="text-align: right;">       -8.21927</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00004</td><td>RUNNING </td><td>10.0.179.4:65</td><td style="text-align: right;">      57</td><td style="text-align: right;">     14</td><td style="text-align: right;">5.80246</td><td style="text-align: right;">    70</td><td style="text-align: right;">         12.1286</td><td style="text-align: right;">          69</td><td style="text-align: right;">       -5.80246</td></tr>
# </tbody>
# </table><br><br>
# Result for decorated_easy_objective_36bc0_00004:
#   date: 2021-09-03_17-13-28
#   done: false
#   experiment_id: bf16f9be9b3644148e068a75743168a1
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 87
#   iterations_since_restore: 88
#   mean_loss: 5.7814332247557
#   neg_mean_loss: -5.7814332247557
#   node_ip: 10.0.179.4
#   pid: 65
#   time_since_restore: 15.366740465164185
#   time_this_iter_s: 0.1664295196533203
#   time_total_s: 15.366740465164185
#   timestamp: 1630689208
#   timesteps_since_restore: 0
#   training_iteration: 88
#   trial_id: 36bc0_00004
#
# Result for decorated_easy_objective_36bc0_00000:
#   date: 2021-09-03_17-13-28
#   done: false
#   experiment_id: df826e3298c242b7891af98d2cf2265c
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 88
#   iterations_since_restore: 89
#   mean_loss: 9.143516100957354
#   neg_mean_loss: -9.143516100957354
#   node_ip: 10.0.179.3
#   pid: 64
#   time_since_restore: 15.409528017044067
#   time_this_iter_s: 0.165879487991333
#   time_total_s: 15.409528017044067
#   timestamp: 1630689208
#   timesteps_since_restore: 0
#   training_iteration: 89
#   trial_id: 36bc0_00000
#
# Result for decorated_easy_objective_36bc0_00002:
#   date: 2021-09-03_17-13-29
#   done: false
#   experiment_id: c1ffe078065b4841858384a55ee9baae
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 88
#   iterations_since_restore: 89
#   mean_loss: 2.619554165037153
#   neg_mean_loss: -2.619554165037153
#   node_ip: 10.0.179.4
#   pid: 66
#   time_since_restore: 15.418017387390137
#   time_this_iter_s: 0.16085195541381836
#   time_total_s: 15.418017387390137
#   timestamp: 1630689209
#   timesteps_since_restore: 0
#   training_iteration: 89
#   trial_id: 36bc0_00002
#
# Result for decorated_easy_objective_36bc0_00003:
#   date: 2021-09-03_17-13-29
#   done: false
#   experiment_id: d824e4a05adf4fb5a7cc5249962b6796
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 89
#   iterations_since_restore: 90
#   mean_loss: 8.215160703456641
#   neg_mean_loss: -8.215160703456641
#   node_ip: 10.0.179.3
#   pid: 65
#   time_since_restore: 15.497490167617798
#   time_this_iter_s: 0.16429924964904785
#   time_total_s: 15.497490167617798
#   timestamp: 1630689209
#   timesteps_since_restore: 0
#   training_iteration: 90
#   trial_id: 36bc0_00003
#
# Result for decorated_easy_objective_36bc0_00001:
#   date: 2021-09-03_17-13-29
#   done: false
#   experiment_id: 2b7b350a3bdf4d22bdff6806e94cf135
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 88
#   iterations_since_restore: 89
#   mean_loss: 6.111701380762931
#   neg_mean_loss: -6.111701380762931
#   node_ip: 10.0.179.4
#   pid: 64
#   time_since_restore: 15.443617105484009
#   time_this_iter_s: 0.1650679111480713
#   time_total_s: 15.443617105484009
#   timestamp: 1630689209
#   timesteps_since_restore: 0
#   training_iteration: 89
#   trial_id: 36bc0_00001
# == Status ==<br>Memory usage on this node: 1.7/7.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 5.0/9 CPUs, 0/0 GPUs, 0.0/9.85 GiB heap, 0.0/4.53 GiB objects (0.0/1.0 CPU_group_0_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_0_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_0_85fbf98a6c73bd089f176d21c53a3f34, 0.0/1.0 CPU_group_0_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_0_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_85fbf98a6c73bd089f176d21c53a3f34)<br>Result logdir: /root/ray_results/mlflow<br>Number of trials: 5/5 (5 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status  </th><th>loc          </th><th style="text-align: right;">  height</th><th style="text-align: right;">  width</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th><th style="text-align: right;">  neg_mean_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>decorated_easy_objective_36bc0_00000</td><td>RUNNING </td><td>10.0.179.3:64</td><td style="text-align: right;">      91</td><td style="text-align: right;">     26</td><td style="text-align: right;">9.13909</td><td style="text-align: right;">    99</td><td style="text-align: right;">         17.3032</td><td style="text-align: right;">          98</td><td style="text-align: right;">       -9.13909</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00001</td><td>RUNNING </td><td>10.0.179.4:64</td><td style="text-align: right;">      61</td><td style="text-align: right;">     97</td><td style="text-align: right;">6.11062</td><td style="text-align: right;">    98</td><td style="text-align: right;">         17.0039</td><td style="text-align: right;">          97</td><td style="text-align: right;">       -6.11062</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00002</td><td>RUNNING </td><td>10.0.179.4:66</td><td style="text-align: right;">      26</td><td style="text-align: right;">     58</td><td style="text-align: right;">2.61756</td><td style="text-align: right;">    99</td><td style="text-align: right;">         17.3228</td><td style="text-align: right;">          98</td><td style="text-align: right;">       -2.61756</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00003</td><td>RUNNING </td><td>10.0.179.3:65</td><td style="text-align: right;">      82</td><td style="text-align: right;">     74</td><td style="text-align: right;">8.21377</td><td style="text-align: right;">    99</td><td style="text-align: right;">         17.2081</td><td style="text-align: right;">          98</td><td style="text-align: right;">       -8.21377</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00004</td><td>RUNNING </td><td>10.0.179.4:65</td><td style="text-align: right;">      57</td><td style="text-align: right;">     14</td><td style="text-align: right;">5.7731 </td><td style="text-align: right;">    98</td><td style="text-align: right;">         17.1056</td><td style="text-align: right;">          97</td><td style="text-align: right;">       -5.7731 </td></tr>
# </tbody>
# </table><br><br>
# Result for decorated_easy_objective_36bc0_00003:
#   date: 2021-09-03_17-13-30
#   done: true
#   experiment_id: d824e4a05adf4fb5a7cc5249962b6796
#   experiment_tag: 3_height=82,width=74
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 99
#   iterations_since_restore: 100
#   mean_loss: 8.213631406761179
#   neg_mean_loss: -8.213631406761179
#   node_ip: 10.0.179.3
#   pid: 65
#   time_since_restore: 17.405672073364258
#   time_this_iter_s: 0.19752287864685059
#   time_total_s: 17.405672073364258
#   timestamp: 1630689210
#   timesteps_since_restore: 0
#   training_iteration: 100
#   trial_id: 36bc0_00003
#
# Result for decorated_easy_objective_36bc0_00000:
#   date: 2021-09-03_17-13-31
#   done: true
#   experiment_id: df826e3298c242b7891af98d2cf2265c
#   experiment_tag: 0_height=91,width=26
#   hostname: ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
#   iterations: 99
#   iterations_since_restore: 100
#   mean_loss: 9.138699690402476
#   neg_mean_loss: -9.138699690402476
#   node_ip: 10.0.179.3
#   pid: 64
#   time_since_restore: 17.478049278259277
#   time_this_iter_s: 0.17486333847045898
#   time_total_s: 17.478049278259277
#   timestamp: 1630689211
#   timesteps_since_restore: 0
#   training_iteration: 100
#   trial_id: 36bc0_00000
#
# Result for decorated_easy_objective_36bc0_00001:
#   date: 2021-09-03_17-13-31
#   done: true
#   experiment_id: 2b7b350a3bdf4d22bdff6806e94cf135
#   experiment_tag: 1_height=61,width=97
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 99
#   iterations_since_restore: 100
#   mean_loss: 6.110402579839801
#   neg_mean_loss: -6.110402579839801
#   node_ip: 10.0.179.4
#   pid: 64
#   time_since_restore: 17.47336721420288
#   time_this_iter_s: 0.1628570556640625
#   time_total_s: 17.47336721420288
#   timestamp: 1630689211
#   timesteps_since_restore: 0
#   training_iteration: 100
#   trial_id: 36bc0_00001
#
# Result for decorated_easy_objective_36bc0_00002:
#   date: 2021-09-03_17-13-31
#   done: true
#   experiment_id: c1ffe078065b4841858384a55ee9baae
#   experiment_tag: 2_height=26,width=58
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 99
#   iterations_since_restore: 100
#   mean_loss: 2.617385257301808
#   neg_mean_loss: -2.617385257301808
#   node_ip: 10.0.179.4
#   pid: 66
#   time_since_restore: 17.48679280281067
#   time_this_iter_s: 0.1640317440032959
#   time_total_s: 17.48679280281067
#   timestamp: 1630689211
#   timesteps_since_restore: 0
#   training_iteration: 100
#   trial_id: 36bc0_00002
#
# Result for decorated_easy_objective_36bc0_00004:
#   date: 2021-09-03_17-13-31
#   done: true
#   experiment_id: bf16f9be9b3644148e068a75743168a1
#   experiment_tag: 4_height=57,width=14
#   hostname: ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
#   iterations: 99
#   iterations_since_restore: 100
#   mean_loss: 5.77163323782235
#   neg_mean_loss: -5.77163323782235
#   node_ip: 10.0.179.4
#   pid: 65
#   time_since_restore: 17.58363103866577
#   time_this_iter_s: 0.16359639167785645
#   time_total_s: 17.58363103866577
#   timestamp: 1630689211
#   timesteps_since_restore: 0
#   training_iteration: 100
#   trial_id: 36bc0_00004
# == Status ==<br>Memory usage on this node: 1.7/7.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/9 CPUs, 0/0 GPUs, 0.0/9.85 GiB heap, 0.0/4.53 GiB objects (0.0/1.0 CPU_group_0_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_73b80f488dac9281148d6b303fbfbba3, 0.0/1.0 CPU_group_0_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_8cb8c9344cbee05ca2d43b9dc4b7ca84, 0.0/1.0 CPU_group_0_85fbf98a6c73bd089f176d21c53a3f34, 0.0/1.0 CPU_group_0_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_ae2624e6b3780b94c28aeb9aab9d2308, 0.0/1.0 CPU_group_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_0_5d188f6b8255b7533bb0b9464d615989, 0.0/1.0 CPU_group_85fbf98a6c73bd089f176d21c53a3f34)<br>Result logdir: /root/ray_results/mlflow<br>Number of trials: 5/5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                          </th><th>status    </th><th>loc  </th><th style="text-align: right;">  height</th><th style="text-align: right;">  width</th><th style="text-align: right;">   loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  iterations</th><th style="text-align: right;">  neg_mean_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>decorated_easy_objective_36bc0_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      91</td><td style="text-align: right;">     26</td><td style="text-align: right;">9.1387 </td><td style="text-align: right;">   100</td><td style="text-align: right;">         17.478 </td><td style="text-align: right;">          99</td><td style="text-align: right;">       -9.1387 </td></tr>
# <tr><td>decorated_easy_objective_36bc0_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      61</td><td style="text-align: right;">     97</td><td style="text-align: right;">6.1104 </td><td style="text-align: right;">   100</td><td style="text-align: right;">         17.4734</td><td style="text-align: right;">          99</td><td style="text-align: right;">       -6.1104 </td></tr>
# <tr><td>decorated_easy_objective_36bc0_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      26</td><td style="text-align: right;">     58</td><td style="text-align: right;">2.61739</td><td style="text-align: right;">   100</td><td style="text-align: right;">         17.4868</td><td style="text-align: right;">          99</td><td style="text-align: right;">       -2.61739</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00003</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      82</td><td style="text-align: right;">     74</td><td style="text-align: right;">8.21363</td><td style="text-align: right;">   100</td><td style="text-align: right;">         17.4057</td><td style="text-align: right;">          99</td><td style="text-align: right;">       -8.21363</td></tr>
# <tr><td>decorated_easy_objective_36bc0_00004</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">      57</td><td style="text-align: right;">     14</td><td style="text-align: right;">5.77163</td><td style="text-align: right;">   100</td><td style="text-align: right;">         17.5836</td><td style="text-align: right;">          99</td><td style="text-align: right;">       -5.77163</td></tr>
# </tbody>
# </table><br><br>
# 2021-09-03 17:13:31,501	INFO tune.py:550 -- Total run time: 21.44 seconds (20.65 seconds for the tuning loop).

# %%
stop_ray_cluster(ray_cluster)
# Out:
# Deleting ray-worker-4bca3e32-3370-4d72-8076-3799b5569e98
# Deleting ray-worker-526e0e9c-77ba-444e-af47-8a2d1ca79925
