# %% [markdown]
# ## Train and Hyperparameter optimization with Ray Tune on 250G of data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import ray; print(f'ray version {ray.__version__}')
import xgboost_ray; print('xgboost_ray', xgboost_ray.__version__)
import xgboost; print('xgboost', xgboost.__version__)
import lightgbm_ray; print('lightgbm_ray', lightgbm_ray.__version__)
import pandas as pd; print('pandas version', pd.__version__)
from lightgbm_ray import RayDMatrix, RayFileType,  RayParams, train
from ray import tune
# Out:
# ray version 1.9.0
# xgboost_ray 0.1.5
# xgboost 1.5.1
# lightgbm_ray 0.1.2
# pandas version 1.2.3

# %%
from hyperplane.ray_common import initialize_ray_cluster, stop_ray_cluster, find_ray_workers
num_workers = 18
cpu_core_per_worker = 15
ram_gb_per_worker = 110 #110 GB allocatible for 16_128 nodes, 12 for 16_16 nodes, 27 for 32_32 nodes
ray_cluster = initialize_ray_cluster(num_workers, cpu_core_per_worker, ram_gb_per_worker)
# Out:
# 👉 Hyperplane: selecting worker node pool
# 2021-12-29 17:06:42,078	INFO services.py:1338 -- View the Ray dashboard at http://10.1.242.3:8787
# 2021-12-29 17:06:42,085	WARNING services.py:1816 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=8.72gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# ray dashboard available at https://shakdemo.hyperplane.dev/ray-stella2/#/
# Waiting for worker ray-worker-cf4a3bf0-2d97-4912-a521-8953a7431bb2...
# Waiting for worker ray-worker-fb059daa-789e-4f1e-9d82-5873dc6aac10...
# Waiting for worker ray-worker-5f702103-d8d9-463d-a75e-30b99a9c7330...
# Waiting for worker ray-worker-3e7de624-3c8f-43a1-9587-056daa6ca192...
# Waiting for worker ray-worker-c7bfd73e-355c-40d7-9d7a-aa799d8ea19b...
# Waiting for worker ray-worker-c9946459-dea6-4e60-8803-de19273b0a8f...
# Waiting for worker ray-worker-fd901a26-d5a1-470a-9cba-026ed9ab72b2...
# Waiting for worker ray-worker-0540e083-66ec-466b-b7a2-6cbf0e09a7fd...
# Waiting for worker ray-worker-11a60c02-f5d6-4bac-8330-ebb6b7706593...
# Waiting for worker ray-worker-c8fc444f-ae1a-45fb-8401-7a246bf3c688...
# Waiting for worker ray-worker-0a20c182-4823-490d-b186-62a66f66e337...
# Waiting for worker ray-worker-2a0e5919-52de-42c9-84ec-b6d736d95c24...
# Waiting for worker ray-worker-259568ff-9c76-4f35-9028-c400388aeb5c...
# Waiting for worker ray-worker-70069876-9a77-4703-b565-aa248a37a9d8...
# Waiting for worker ray-worker-c6f5bd2f-e23d-42aa-9cf0-517bee1133e2...
# Waiting for worker ray-worker-aab63b9b-0581-4ca9-889c-099ab25ee657...
# Waiting for worker ray-worker-0165ee76-dd0e-445b-8ff8-6e2d04d81522...
# Waiting for worker ray-worker-3d59b1ac-920b-4e65-af99-57ed7070a2c8...

# %%
# wrapper train and HPO function for one liner train, MLFlow logging
# sklearn like api

# %%
def train(config):
    train_set = (RayDMatrix(file_path))
    lightgbm_ray.train(train_set, config)

# %%
from ray import tune

config = {}

analysis = tune(train, params=config)

# %%
## list of models ray support 
lightgbm_ray
xgboost_ray
sklearn
tensorflow, pytorch, pytorch_lighting (simple model )

# %%
from google.cloud import storage
import os
storage_client = storage.Client()
bucket = os.environ['HYPERPLANE_GCP_BUCKET']
print(bucket)
blobs = storage_client.list_blobs(bucket, prefix = 'data/crypto2/')  #fake_stock_train
blob_names= [i.name for i in blobs]
print(f'number of files {len(blob_names)}')
file_list = [f"gs://{bucket}/{i}" for i in blob_names if '.parquet' in i]
file_list[:2]
# Out:
# shakdemo-hyperplane
# number of files 4168
# ['gs://shakdemo-hyperplane/data/crypto2/0.parquet',
#  'gs://shakdemo-hyperplane/data/crypto2/1.parquet']

# %%
## estimate file size

# %%
n_files = len(file_list)
# n_files = 4000
df_test = pd.read_parquet(file_list[0], columns = ['order', 'type', 'takerOrMaker', 'amount', 'cost', 'fee','price'])
one_file_size= df_test.memory_usage(deep = True, index = True).sum()/1024/1024
print(f'per file size {one_file_size} MB')
total_file_size = one_file_size * n_files

print(f'total file size {total_file_size/1024.} GB')
# Out:
# per file size 61.416748046875 MB
# total file size 249.9853572845459 GB

# %% [markdown]
# ## train model

# %%
## working combo 
## num_of_actors 60 , 10 of 12_16 workers, 500 files, ~ 15G data 
## num_of_actors 112, 18 of 12_128 workers, n_files, ~ 250G data

# %%
num_of_actors = 112

# %%
config = {
            "objective": "regression_l2",
            "metric": ["rmse"],
        }

ray_params = RayParams(num_actors=num_of_actors, cpus_per_actor=2)

# %%
use_cols =  ['order', 'type', 'takerOrMaker', 'amount', 'cost', 'fee','price']

# %%
def train_model(config):
    
    train_set = RayDMatrix(
        file_list[:n_files],
        num_actors = num_of_actors,
        distributed = True,
        columns=use_cols, 
        label="price",  # Will select this column as the label
        filetype=RayFileType.PARQUET)
    
    # train_set.assert_enough_shards_for_actors(num_actors=6)

    evals_result = {}
    
    bst = train(
        params=config,
        dtrain = train_set,
        evals_result=evals_result,
        valid_sets=[train_set],
        valid_names=["train"],
        verbose_eval=False,
        ray_params= ray_params,
        verbose = 0
    )

# %%
# %%time
train_model(config)
# Out:
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.23.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.23.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.16.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.14.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.17.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.29.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.29.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.29.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.29.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.29.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.32.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.21.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.20.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.20.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.20.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.20.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.20.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.24.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) [LightGBM] [Info] Trying to bind port 59889...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) [LightGBM] [Info] Binding port 59889 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) [LightGBM] [Info] Trying to bind port 57525...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) [LightGBM] [Info] Binding port 57525 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) [LightGBM] [Info] Trying to bind port 51759...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) [LightGBM] [Info] Binding port 51759 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) [LightGBM] [Info] Trying to bind port 43311...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) [LightGBM] [Info] Binding port 43311 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) [LightGBM] [Info] Trying to bind port 44597...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) [LightGBM] [Info] Binding port 44597 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) [LightGBM] [Info] Trying to bind port 58021...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) [LightGBM] [Info] Binding port 58021 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) [LightGBM] [Info] Trying to bind port 57961...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) [LightGBM] [Info] Binding port 57961 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) [LightGBM] [Info] Trying to bind port 57657...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) [LightGBM] [Info] Binding port 57657 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) [LightGBM] [Info] Trying to bind port 53083...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) [LightGBM] [Info] Binding port 53083 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) [LightGBM] [Info] Trying to bind port 59655...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) [LightGBM] [Info] Binding port 59655 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) [LightGBM] [Info] Trying to bind port 36121...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) [LightGBM] [Info] Binding port 36121 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) [LightGBM] [Info] Trying to bind port 45017...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) [LightGBM] [Info] Binding port 45017 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) [LightGBM] [Info] Trying to bind port 58449...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) [LightGBM] [Info] Binding port 58449 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) [LightGBM] [Info] Trying to bind port 49455...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) [LightGBM] [Info] Binding port 49455 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) [LightGBM] [Info] Trying to bind port 56595...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) [LightGBM] [Info] Binding port 56595 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) [LightGBM] [Info] Trying to bind port 40393...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) [LightGBM] [Info] Binding port 40393 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 34087...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) [LightGBM] [Info] Binding port 34087 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 33239...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) [LightGBM] [Info] Binding port 33239 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 51299...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) [LightGBM] [Info] Binding port 51299 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 39537...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) [LightGBM] [Info] Binding port 39537 succeeded
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) [LightGBM] [Info] Trying to bind port 53653...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) [LightGBM] [Info] Binding port 53653 succeeded
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) [LightGBM] [Info] Trying to bind port 58273...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) [LightGBM] [Info] Binding port 58273 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.23.3) [LightGBM] [Info] Trying to bind port 49867...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.23.3) [LightGBM] [Info] Binding port 49867 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.23.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.23.3) [LightGBM] [Info] Trying to bind port 38383...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.23.3) [LightGBM] [Info] Binding port 38383 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.23.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.16.3) [LightGBM] [Info] Trying to bind port 47015...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.16.3) [LightGBM] [Info] Binding port 47015 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.16.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.16.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.14.3) [LightGBM] [Info] Trying to bind port 59731...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.14.3) [LightGBM] [Info] Binding port 59731 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.14.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.14.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.17.3) [LightGBM] [Info] Trying to bind port 54329...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.17.3) [LightGBM] [Info] Binding port 54329 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.17.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.17.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.29.3) [LightGBM] [Info] Trying to bind port 34309...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.29.3) [LightGBM] [Info] Binding port 34309 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.29.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.29.3) [LightGBM] [Info] Trying to bind port 39483...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.29.3) [LightGBM] [Info] Binding port 39483 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.29.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.29.3) [LightGBM] [Info] Trying to bind port 48955...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.29.3) [LightGBM] [Info] Binding port 48955 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.29.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.29.3) [LightGBM] [Info] Trying to bind port 57385...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.29.3) [LightGBM] [Info] Binding port 57385 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.29.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.29.3) [LightGBM] [Info] Trying to bind port 39939...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.29.3) [LightGBM] [Info] Binding port 39939 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.29.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) [LightGBM] [Info] Trying to bind port 45599...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) [LightGBM] [Info] Binding port 45599 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.32.3) [LightGBM] [Info] Trying to bind port 59811...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.32.3) [LightGBM] [Info] Binding port 59811 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.32.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.21.3) [LightGBM] [Info] Trying to bind port 52529...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.21.3) [LightGBM] [Info] Binding port 52529 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.21.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.21.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.20.3) [LightGBM] [Info] Trying to bind port 54023...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.20.3) [LightGBM] [Info] Binding port 54023 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.20.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.20.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.20.3) [LightGBM] [Info] Trying to bind port 51433...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.20.3) [LightGBM] [Info] Binding port 51433 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.20.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.20.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.20.3) [LightGBM] [Info] Trying to bind port 44257...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.20.3) [LightGBM] [Info] Binding port 44257 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.20.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.20.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.20.3) [LightGBM] [Info] Trying to bind port 43923...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.20.3) [LightGBM] [Info] Binding port 43923 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.20.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.20.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.24.3) [LightGBM] [Info] Trying to bind port 41809...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.24.3) [LightGBM] [Info] Binding port 41809 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.24.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.24.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.20.3) [LightGBM] [Info] Trying to bind port 37445...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.20.3) [LightGBM] [Info] Binding port 37445 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.20.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.20.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 50873...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.15.3) [LightGBM] [Info] Binding port 50873 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 40813...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.15.3) [LightGBM] [Info] Binding port 40813 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=87, ip=10.2.25.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.31.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.28.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.28.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=1498) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=1497) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.16.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.16.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.14.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.16.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.32.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.32.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.32.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.32.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.27.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.30.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=87, ip=10.2.21.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.21.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.21.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.24.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.20.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.15.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.31.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.31.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.31.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.31.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.28.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.28.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.28.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.28.2) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.18.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.18.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.14.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.16.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.14.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.14.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=86, ip=10.2.17.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.27.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=82, ip=10.2.27.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.27.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=84, ip=10.2.27.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.21.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=83, ip=10.2.24.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=81, ip=10.2.24.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=85, ip=10.2.25.3) UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# (_RemoteRayLightGBMActor pid=87, ip=10.2.25.3) [LightGBM] [Info] Trying to bind port 43195...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.25.3) [LightGBM] [Info] Binding port 43195 succeeded
# (_RemoteRayLightGBMActor pid=87, ip=10.2.25.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.25.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.31.2) [LightGBM] [Info] Trying to bind port 54825...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.31.2) [LightGBM] [Info] Binding port 54825 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.31.2) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.31.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.28.2) [LightGBM] [Info] Trying to bind port 52843...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.28.2) [LightGBM] [Info] Binding port 52843 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.28.2) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.28.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.28.2) [LightGBM] [Info] Trying to bind port 36211...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.28.2) [LightGBM] [Info] Binding port 36211 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.28.2) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.28.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=1498) [LightGBM] [Info] Trying to bind port 55651...
# (_RemoteRayLightGBMActor pid=1498) [LightGBM] [Info] Binding port 55651 succeeded
# (_RemoteRayLightGBMActor pid=1498) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=1498) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=1497) [LightGBM] [Info] Trying to bind port 47443...
# (_RemoteRayLightGBMActor pid=1497) [LightGBM] [Info] Binding port 47443 succeeded
# (_RemoteRayLightGBMActor pid=1497) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=1497) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.16.3) [LightGBM] [Info] Trying to bind port 59231...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.16.3) [LightGBM] [Info] Binding port 59231 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.16.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.16.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.16.3) [LightGBM] [Info] Trying to bind port 49621...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.16.3) [LightGBM] [Info] Binding port 49621 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.16.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.16.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.16.3) [LightGBM] [Info] Trying to bind port 39605...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.16.3) [LightGBM] [Info] Binding port 39605 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.16.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.16.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.14.3) [LightGBM] [Info] Trying to bind port 32877...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.14.3) [LightGBM] [Info] Binding port 32877 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.14.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.14.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.32.3) [LightGBM] [Info] Trying to bind port 50553...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.32.3) [LightGBM] [Info] Binding port 50553 succeeded
# (_RemoteRayLightGBMActor pid=83, ip=10.2.32.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=83, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.32.3) [LightGBM] [Info] Trying to bind port 36567...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.32.3) [LightGBM] [Info] Binding port 36567 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.32.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.32.3) [LightGBM] [Info] Trying to bind port 40713...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.32.3) [LightGBM] [Info] Binding port 40713 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.32.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.32.3) [LightGBM] [Info] Trying to bind port 59207...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.32.3) [LightGBM] [Info] Binding port 59207 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.32.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.32.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.27.3) [LightGBM] [Info] Trying to bind port 43659...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.27.3) [LightGBM] [Info] Binding port 43659 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.27.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.27.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.30.3) [LightGBM] [Info] Trying to bind port 50127...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.30.3) [LightGBM] [Info] Binding port 50127 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.30.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.30.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=87, ip=10.2.21.3) [LightGBM] [Info] Trying to bind port 48727...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.21.3) [LightGBM] [Info] Binding port 48727 succeeded
# (_RemoteRayLightGBMActor pid=87, ip=10.2.21.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=87, ip=10.2.21.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.21.3) [LightGBM] [Info] Trying to bind port 49199...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.21.3) [LightGBM] [Info] Binding port 49199 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.21.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.21.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.21.3) [LightGBM] [Info] Trying to bind port 36391...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.21.3) [LightGBM] [Info] Binding port 36391 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.21.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.21.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=86, ip=10.2.24.3) [LightGBM] [Info] Trying to bind port 47477...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.24.3) [LightGBM] [Info] Binding port 47477 succeeded
# (_RemoteRayLightGBMActor pid=86, ip=10.2.24.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=86, ip=10.2.24.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.20.3) [LightGBM] [Info] Trying to bind port 38603...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.20.3) [LightGBM] [Info] Binding port 38603 succeeded
# (_RemoteRayLightGBMActor pid=84, ip=10.2.20.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.20.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=85, ip=10.2.15.3) [LightGBM] [Info] Trying to bind port 59113...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.15.3) [LightGBM] [Info] Binding port 59113 succeeded
# (_RemoteRayLightGBMActor pid=85, ip=10.2.15.3) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=85, ip=10.2.15.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=82, ip=10.2.31.2) [LightGBM] [Info] Trying to bind port 57269...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.31.2) [LightGBM] [Info] Binding port 57269 succeeded
# (_RemoteRayLightGBMActor pid=82, ip=10.2.31.2) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=82, ip=10.2.31.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 260 milliseconds
# (_RemoteRayLightGBMActor pid=81, ip=10.2.31.2) [LightGBM] [Info] Trying to bind port 55897...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.31.2) [LightGBM] [Info] Binding port 55897 succeeded
# (_RemoteRayLightGBMActor pid=81, ip=10.2.31.2) [LightGBM] [Info] Listening...
# (_RemoteRayLightGBMActor pid=81, ip=10.2.31.2) [LightGBM] [Warning] Connecting to rank 111 failed, waiting for 200 milliseconds
# ...
# (_RemoteRayLightGBMActor pid=84, ip=10.2.30.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.13.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.18.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.18.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.18.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.18.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.31.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.31.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.28.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.28.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.23.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.23.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.23.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.23.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.14.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.14.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.14.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.14.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.14.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.17.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.16.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.17.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.16.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.16.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.16.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.16.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.29.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.16.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.29.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.27.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.27.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.27.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.27.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.27.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.32.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.32.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.32.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.32.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.32.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.32.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.20.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.20.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.20.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.20.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.20.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.20.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.24.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.24.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.24.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.24.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.24.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.12.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.12.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.30.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.12.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.12.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.30.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.12.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.12.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=87, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.21.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.25.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.25.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.25.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.25.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=87, ip=10.2.25.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.25.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=87, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.15.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.13.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.13.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.13.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.13.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=87, ip=10.2.13.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.18.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.18.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.31.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.31.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.31.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.31.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.28.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.28.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.28.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.28.2) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.23.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.23.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.14.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.17.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=82, ip=10.2.17.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.17.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.17.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=84, ip=10.2.29.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=83, ip=10.2.29.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.29.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=85, ip=10.2.29.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=86, ip=10.2.27.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=81, ip=10.2.24.3) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=1498) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# (_RemoteRayLightGBMActor pid=1497) [LightGBM] [Warning] num_threads is set=2, n_jobs=-1 will be ignored. Current value: num_threads=2
# CPU times: user 7.05 s, sys: 2.09 s, total: 9.15 s
# Wall time: 1min 9s

# %% [markdown]
# ## Train with Hyperplarameter optimization with Ray Tune

# %%
# num_of_actors = 28

# %%
# Specify the hyperparameter search space.
config = {
    "objective": "regression_l2",
    "metric": ["rmse"],    
    "eta": tune.loguniform(1e-4, 1e-2),
    # "subsample": tune.uniform(0.8, 1.0),
    "max_depth": tune.randint(7, 9)
}

ray_params = RayParams(num_actors=num_of_actors, cpus_per_actor=2)

def train_model(config):
    
    train_set = RayDMatrix(
        file_list[:n_files],
        num_actors = num_of_actors,
        distributed = True,
        columns=use_cols, 
        label="price",  # Will select this column as the label
        filetype=RayFileType.PARQUET)

    evals_result = {}
    
    bst = train(
        params=config,
        dtrain = train_set,
        evals_result=evals_result,
        valid_sets=[train_set],
        valid_names=["train"],
        verbose_eval=False,
        ray_params= ray_params,
        verbose = 1
    )

# %%
# %%time


# Make sure to use the `get_tune_resources` method to set the `resources_per_trial`
analysis = tune.run(
    train_model,
    config=config,
    metric="train-rmse",
    mode="min",
    resources_per_trial=ray_params.get_tune_resources(),
    verbose = 1)

print("Best hyperparameters", analysis.best_config)
# Out:
# == Status ==<br>Current time: 2021-12-29 17:19:19 (running for 00:00:57.11)<br>Memory usage on this node: 2.2/31.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/277 CPUs, 0/0 GPUs, 0.0/1401.25 GiB heap, 0.0/601.67 GiB objects<br>Current best trial: 528f7_00000 with train-rmse=185.49726146933259 and parameters={'objective': 'regression_l2', 'metric': ['rmse']}<br>Result logdir: /root/ray_results/train_model_2021-12-29_17-18-21<br>Number of trials: 1/1 (1 TERMINATED)<br><br>
# 2021-12-29 17:19:19,226	INFO tune.py:626 -- Total run time: 57.84 seconds (57.10 seconds for the tuning loop).
# Best hyperparameters {'objective': 'regression_l2', 'metric': ['rmse']}
# CPU times: user 4.31 s, sys: 1.34 s, total: 5.65 s
# Wall time: 57.9 s

# %%
analysis.results_df
# Out:
#              train-rmse  time_this_iter_s  done timesteps_total  \
# trial_id
# 528f7_00000  185.497261          2.434112  True            None
#
#             episodes_total  training_iteration  \
# trial_id
# 528f7_00000           None                  10
#
#                                 experiment_id                 date  \
# trial_id
# 528f7_00000  4fdcaee6abea4fb0b98c60c43596e09d  2021-12-29_17-19-19
#
#               timestamp  time_total_s  pid  \
# trial_id
# 528f7_00000  1640798359     54.145826  514
#
#                                                     hostname    node_ip  \
# trial_id
# 528f7_00000  ray-worker-70069876-9a77-4703-b565-aa248a37a9d8  10.2.14.3
#
#              time_since_restore  timesteps_since_restore  \
# trial_id
# 528f7_00000           54.145826                        0
#
#              iterations_since_restore experiment_tag config.objective  \
# trial_id
# 528f7_00000                        10              0    regression_l2
#
#             config.metric
# trial_id
# 528f7_00000        [rmse]

# %%
# bst.booster_.save_model("model.lgbm")

# %%
stop_ray_cluster(ray_cluster)
# Out:
# Deleting ray-worker-cf4a3bf0-2d97-4912-a521-8953a7431bb2
# Deleting ray-worker-fb059daa-789e-4f1e-9d82-5873dc6aac10
# Deleting ray-worker-5f702103-d8d9-463d-a75e-30b99a9c7330
# Deleting ray-worker-3e7de624-3c8f-43a1-9587-056daa6ca192
# Deleting ray-worker-c7bfd73e-355c-40d7-9d7a-aa799d8ea19b
# Deleting ray-worker-c9946459-dea6-4e60-8803-de19273b0a8f
# Deleting ray-worker-fd901a26-d5a1-470a-9cba-026ed9ab72b2
# Deleting ray-worker-0540e083-66ec-466b-b7a2-6cbf0e09a7fd
# Deleting ray-worker-11a60c02-f5d6-4bac-8330-ebb6b7706593
# Deleting ray-worker-c8fc444f-ae1a-45fb-8401-7a246bf3c688
# Deleting ray-worker-0a20c182-4823-490d-b186-62a66f66e337
# Deleting ray-worker-2a0e5919-52de-42c9-84ec-b6d736d95c24
# Deleting ray-worker-259568ff-9c76-4f35-9028-c400388aeb5c
# Deleting ray-worker-70069876-9a77-4703-b565-aa248a37a9d8
# Deleting ray-worker-c6f5bd2f-e23d-42aa-9cf0-517bee1133e2
# Deleting ray-worker-aab63b9b-0581-4ca9-889c-099ab25ee657
# Deleting ray-worker-0165ee76-dd0e-445b-8ff8-6e2d04d81522
# Deleting ray-worker-3d59b1ac-920b-4e65-af99-57ed7070a2c8
